# %%
#importing required packages

# %%
 pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np

# %%
import pandas as pd

# %%
pip install quandl
# Out:
# ...
#   Using cached Quandl-3.7.0-py2.py3-none-any.whl (26 kB)
# ...
#   Using cached more_itertools-9.1.0-py3-none-any.whl (54 kB)
# ...
#   Using cached inflection-0.5.1-py2.py3-none-any.whl (9.5 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import quandl as q

# %%
import requests

# %%
pip install xlsxwriter
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 152.8/152.8 kB 2.4 MB/s eta 0:00:00a 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import xlsxwriter
import math

# %%
# set the API key

# %%
pip install nasdaq-data-link
# Out:
# ...
#   Using cached Nasdaq_Data_Link-1.0.4-py2.py3-none-any.whl (28 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import nasdaqdatalink

# %%
#Extracting data from the Quandl API

# %%
q.ApiConfig.api_key = "t3rDCnhuVLsmzTq2Yy8b"

# %%
#send a get request to query Microsoft's end of day stock prices from 1st #Jan, 2010 to 1st Jan, 2019

# %%
q.ApiConfig.api_key = 't3rDCnhuVLsmzTq2Yy8b'
q.get_table('QUOTEMEDIA/PRICES', date='2017-10-31,2017-10-30,2017-10-27', ticker='XOM')
# Out:
#      ticker       date   open   high    low  close      volume  dividend  \
# None
# 0       XOM 2017-10-31  83.65  83.68  83.17  83.35   9754213.0       0.0
# 1       XOM 2017-10-30  83.71  83.95  83.41  83.54   7811022.0       0.0
# 2       XOM 2017-10-27  83.00  84.24  82.01  83.71  14866246.0       0.0
#
#       split   adj_open   adj_high    adj_low  adj_close  adj_volume
# None
# 0       1.0  63.226346  63.249022  62.863541  62.999593   9754213.0
# 1       1.0  63.271697  63.453100  63.044944  63.143204   7811022.0
# 2       1.0  62.735048  63.672294  61.986762  63.271697  14866246.0

# %%
msft_data=q.get_table('QUOTEMEDIA/PRICES', ticker='XOM')

# %%
msft_data.head()
# Out:
#      ticker       date   open   high      low   close      volume  dividend  \
# None
# 0       XOM 2017-10-31  83.65  83.68  83.1700  83.350   9754213.0       0.0
# 1       XOM 2017-10-30  83.71  83.95  83.4100  83.540   7811022.0       0.0
# 2       XOM 2017-10-27  83.00  84.24  82.0100  83.710  14866246.0       0.0
# 3       XOM 2017-10-26  83.37  83.65  83.1100  83.470   9152415.0       0.0
# 4       XOM 2017-10-25  83.45  83.73  82.9465  83.195   7654137.0       0.0
#
#       split   adj_open   adj_high    adj_low  adj_close  adj_volume
# None
# 0       1.0  63.226346  63.249022  62.863541  62.999593   9754213.0
# 1       1.0  63.271697  63.453100  63.044944  63.143204   7811022.0
# 2       1.0  62.735048  63.672294  61.986762  63.271697  14866246.0
# 3       1.0  63.014710  63.226346  62.818191  63.090294   9152415.0
# 4       1.0  63.075178  63.286814  62.694610  62.882437   7654137.0

# %%
msft_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42 entries, 0 to 41
# Data columns (total 14 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ticker      42 non-null     object
#  1   date        42 non-null     datetime64[ns]
#  2   open        42 non-null     float64
#  3   high        42 non-null     float64
#  4   low         42 non-null     float64
#  5   close       42 non-null     float64
#  6   volume      42 non-null     float64
#  7   dividend    42 non-null     float64
#  8   split       42 non-null     float64
#  9   adj_open    42 non-null     float64
#  10  adj_high    42 non-null     float64
#  11  adj_low     42 non-null     float64
#  12  adj_close   42 non-null     float64
#  13  adj_volume  42 non-null     float64
# dtypes: datetime64[ns](1), float64(12), object(1)
# memory usage: 4.7+ KB

# %%
msft_data.describe()
# Out:
#             open       high        low      close        volume  dividend  \
# count  42.000000  42.000000  42.000000  42.000000  4.200000e+01      42.0
# mean   81.178571  81.581581  80.939443  81.337976  9.217467e+06       0.0
# std     1.844482   1.818219   1.809087   1.777546  2.929739e+06       0.0
# min    76.370000  76.850000  76.320000  76.570000  5.734007e+06       0.0
# 25%    79.895000  80.247500  79.715000  80.075000  7.254144e+06       0.0
# 50%    81.675000  81.930000  81.402500  81.775000  8.515198e+06       0.0
# 75%    82.682500  83.030000  82.352500  82.755000  9.916155e+06       0.0
# max    83.710000  84.240000  83.410000  83.710000  1.857438e+07       0.0
#
#        split   adj_open   adj_high    adj_low  adj_close    adj_volume
# count   42.0  42.000000  42.000000  42.000000  42.000000  4.200000e+01
# mean     1.0  61.358332  61.662944  61.177588  61.478817  9.217467e+06
# std      0.0   1.394141   1.374290   1.367388   1.343547  2.929739e+06
# ...

# %%
msft_data
# Out:
#      ticker       date   open     high      low   close      volume  dividend  \
# None
# 0       XOM 2017-10-31  83.65  83.6800  83.1700  83.350   9754213.0       0.0
# 1       XOM 2017-10-30  83.71  83.9500  83.4100  83.540   7811022.0       0.0
# 2       XOM 2017-10-27  83.00  84.2400  82.0100  83.710  14866246.0       0.0
# 3       XOM 2017-10-26  83.37  83.6500  83.1100  83.470   9152415.0       0.0
# 4       XOM 2017-10-25  83.45  83.7300  82.9465  83.195   7654137.0       0.0
# 5       XOM 2017-10-24  83.55  83.8065  83.3100  83.470   7551105.0       0.0
# 6       XOM 2017-10-23  83.15  83.7600  83.0401  83.240   9829846.0       0.0
# 7       XOM 2017-10-20  82.85  83.1300  82.6200  83.110   9574086.0       0.0
# 8       XOM 2017-10-19  82.35  83.0500  82.3300  82.740   7945461.0       0.0
# 9       XOM 2017-10-18  82.96  83.3910  82.5400  82.760   6367060.0       0.0
# 10      XOM 2017-10-17  82.63  82.9700  82.5400  82.960   6443821.0       0.0
# ...

# %%
# Import numpy package
import numpy as np

# %%
# assign `Adj Close` to `daily_close`
daily_close = msft_data[['adj_close']]

# %%
# returns as fractional change
daily_return = daily_close.pct_change()

# %%
# replacing NA values with 0

daily_return.fillna(0, inplace=True)

# %%
print(daily_return)
# Out:
#       adj_close
# None
# 0      0.000000
# 1      0.002280
# 2      0.002035
# 3     -0.002867
# 4     -0.003295
# 5      0.003305
# 6     -0.002755
# 7     -0.001562
# 8     -0.004452
# 9      0.000242
# 10     0.002417
# 11    -0.001808
# 12    -0.004830
# 13     0.000243
# 14     0.002062
# 15    -0.004116
# 16    -0.002796
# 17    -0.003901
# 18     0.003794
# 19    -0.002804
# 20    -0.000367
# 21    -0.001590
# 22     0.004288
# 23     0.002562
# 24    -0.009247
# 25    -0.006631
# 26     0.001113
# 27    -0.013090
# 28    -0.000375
# 29     0.008261
# 30    -0.004097
# 31    -0.001621
# 32    -0.000250
# 33     0.000250
# 34    -0.003996
# 35    -0.003385
# 36    -0.003145
# 37    -0.005426
# 38     0.002664
# 39    -0.003163
# 40    -0.020310
# 41    -0.007904

# %%
perc_change=daily_return*100

# %%
print(perc_change)
# Out:
#       adj_close
# None
# 0      0.000000
# 1      0.227954
# 2      0.203495
# 3     -0.286704
# 4     -0.329460
# 5      0.330549
# 6     -0.275548
# 7     -0.156175
# 8     -0.445193
# 9      0.024172
# 10     0.241663
# 11    -0.180810
# 12    -0.483033
# 13     0.024269
# 14     0.206236
# 15    -0.411622
# 16    -0.279601
# 17    -0.390101
# 18     0.379391
# 19    -0.280419
# 20    -0.036679
# 21    -0.159002
# 22     0.428764
# 23     0.256160
# 24    -0.924687
# 25    -0.663146
# 26     0.111262
# 27    -1.308965
# 28    -0.037538
# 29     0.826136
# 30    -0.409683
# 31    -0.162054
# 32    -0.024972
# 33     0.024978
# 34    -0.399551
# 35    -0.338473
# 36    -0.314465
# 37    -0.542587
# 38     0.266430
# 39    -0.316336
# 40    -2.030972
# 41    -0.790360
